# %%
# Function Copy

def welcome():
    print('Welcome to the Island')

# %%
welcome()
# Out:
# Welcome to the Island

# %%
wel=welcome     #function welcome() is copied to wel
print(wel())
# Out:
# Welcome to the Island
# None

# %%
del welcome
welcome()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 del welcome
# ----> 2 welcome()
#
# NameError: name 'welcome' is not defined

# %%
wel()
# Out:
# Welcome to the Island
