# %% [markdown]
# **Workflow:-**
# 1. Data Cleaning and Preprocessing
# 2. Train, Test Split
# 3. TF-IDF/BOW
# 4. Model Training
# 5. Making Predictions
# 6. Performance Evaluation

# %%
# importing basic libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing our dataset

messages=pd.read_csv('SMSSpamCollection.csv')
messages.head()
# Out:
#   Label                                            Message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# importing NLP libraries

import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
ps=PorterStemmer()

# %%
corpus=[]

for i in range(0, len(messages)):
    review=re.sub('[^a-zA-Z]', ' ', messages['Message'][i])
    review=review.lower()
    review=review.split()
    review=[ps.stem(word) for word in review if not word in stopwords.words()]
    review=' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['jurong point crazi avail bugi great world buffet amor',
#  'lar joke wif',
#  'free entri wkli comp win cup final tkt st text receiv entri question std txt rate appli',
#  'dun earli',
#  'usf live',
#  'freemsg hey darl week word back fun tb xxx std chg send rcv',
#  'brother speak treat aid patent',
#  'request mell mell oru minnaminungint nurungu vettam set callertun caller press copi friend callertun',
#  'winner valu network custom select receivea prize reward claim call claim code kl valid hour',
#  'mobil month r entitl updat latest colour mobil camera free call mobil updat co free',
#  'gonna home talk stuff anymor tonight cri today',
#  'chanc win cash pound txt csh send cost p day day tsandc appli repli hl info',
#  'urgent week free membership prize jackpot txt word claim www dbuk net lccltd pobox ldnw rw',
#  'search word breather promis grant fulfil promis wonder bless time',
#  'date sunday',
#  'xxxmobilemovieclub credit click wap link txt messag click http wap xxxmobilemovieclub qjkgighjjgcbl',
#  'watch',
#  'rememb spell naughti make wet',
#  'fine feel gota b',
#  'england macedonia miss goal team news txt ur nation team england wale scotland txt poboxox w wq',
#  'spell',
#  'month joke',
#  'pay lar stock comin',
#  'aft finish lunch str ard smth finish ur lunch',
#  'ffffffffff alright meet sooner',
#  'forc eat slice hungri suck mark worri sick turn pizza',
#  'convinc',
#  'catch bu fri egg make tea eat mom left dinner feel love',
#  'back amp pack car room',
#  'ahhh work vagu rememb feel',
#  'wait clear sarcast x live',
#  'apologet fallen actin spoilt child caught badli cheer',
#  '',
#  'fear faint housework quick cuppa',
#  'subscript rington uk mobil charg month confirm repli repli charg',
#  'home time msg xuhui learn lesson',
#  'oop roommat',
#  'letter b car',
#  'decid',
#  'saturday text decid tomo invit',
#  'pl ahead watt want great weekend abiola',
#  'forget crave love sweet arabian steed mmmmmm yummi',
#  'rodger burn msg call repli sm free nokia mobil free camcord call deliveri tomorrow',
#  '',
#  'great hope endow lt gt inch',
#  'call messag miss call',
#  'b immunis nigeria',
#  'fair',
#  'tyler bit',
#  'stubborn hospit tell mark weak sucker hospit weak sucker',
#  'think time class',
#  'gram run lt gt half eighth smarter gram lt gt',
#  'fyi x ride earli tomorrow morn crash place tonight',
#  'wow realiz embarass accomod happi cave sorri give sorri offer sorri room embarass',
#  'sm ac sptv jersey devil detroit red wing play ice hockey correct incorrect repli sptv',
#  'mallika sherawat yesterday find lt url gt',
#  'congrat year special cinema pass call suprman matrix starwar free bx ip pm miss',
#  'sorri call meet',
#  'reach',
#  'gauti sehwag odi seri',
#  'gonna pick burger home move pain kill',
#  'joke girl situat seeker',
#  'part check iq',
#  'sorri roommat forev',
#  'lar doubl check wif hair dresser wun cut short cut nice',
#  'valu custom pleas advis recent review mob award bonu prize call',
#  'today song dedic day song dedic send ur valuabl frnd rpli',
#  'urgent ur award complimentari trip eurodisinc trav aco entri claim txt di morefrmmob shracomorsglsuplt ls aj',
#  'hear divorc barbi ken stuff',
#  'plane give month',
#  'lucki save money hee',
#  'finish class',
#  'babe home wanna xx',
#  'perform',
#  'call',
#  'wait machan call free',
#  'cool gentleman treat digniti respect',
#  'peopl shi',
#  'oper lt gt',
#  'job earn',
#  'sorri call',
#  'call',
#  'home',
#  'place',
#  'stop',
#  'call network urgnt sm',
#  'real ticket jacket multi',
#  'start send request make pain back back bed doubl coin factori gotta cash nitro',
#  'tonight babe',
#  'kano download wen ur free',
#  'stand close catch',
#  'sorri pain meet night spent late afternoon casualti mean stuff moro includ time sheet sorri',
#  'smile pleasur smile pain smile troubl pour rain smile sum hurt smile becoz love smile',
#  'call custom servic repres pm guarante cash prize',
#  'plan buy check lido show afternoon finish work',
#  'free rington wait collect simpli text password mix verifi usher britney fml box mk ppw',
#  'watch telugu movi abt',
#  'finish load loan pay',
#  'wk hol bit run forgot hairdress appoint home shower prob',
#  'cup coffe anim',
#  'text anymor',
#  'ur price long legal wen pick ave x am xx',
#  'car buy drive test',
#  'request mell mell oru minnaminungint nurungu vettam set callertun caller press copi friend callertun',
#  'wow guess gave boston chang search locat nyc chang cuz signin page boston',
#  'umma life vava umma love lot dear',
#  'lot wish birthday make birthday memor',
#  'aight hit cash',
#  'ip address test consid comput minecraft server',
#  'grumpi mom lie play joke',
#  'worri guess busi',
#  'plural noun research',
#  'dinner msg',
#  'wif co thing scare dun mah co loud',
#  'gent contact weekend draw show prize guarante call claim code valid hr ppm',
#  'wa ur openin sentenc formal fine juz tt eatin puttin weight haha anythin special happen',
#  'enter cabin happi b day boss felt special askd lunch lunch invit apart',
#  'winner special select receiv holiday flight speak live oper claim p',
#  'goodo speak friday egg potato ratio tortilla need',
#  'uncl inform pay school directli pl buy food',
#  'privat account statement show unredeem bonu point claim call identifi code expir',
#  'urgent mobil award bonu caller prize final contact call landlin box wr ppm',
#  'address appl pair malarki',
#  'today voda number end select receiv award match call quot claim code standard rate app',
#  'sao today',
#  'predict time finish buy',
#  'stuff',
#  'yetund money text bother send involv impos place apologis',
#  'room',
#  'hey girl r hope r r bak long time give call sum time lucyxx',
#  'cost',
#  'home',
#  'dear call tmorrow pl accomod',
#  'answer question',
#  'sunshin quiz wkli win top soni dvd player countri algarv txt ansr sp tyron',
#  'laid tonight real dog locat direct ur mob join uk largest dog network bt txting gravel nt ec p msg p',
#  'haf msn yiju hotmail',
#  'call meet',
#  'check room befor activ',
#  'rcv msg chat svc free hardcor servic text age verifi yr network',
#  'lazi type forgot lect pouch nice',
#  'text',
#  'sir wait mail',
#  'swt nver tire thing lovabl person coz somtim thing occupi biggest part heart gud',
#  'pl open back',
#  'dot',
#  'what staff take class',
#  'freemsg repli text randi sexi femal live local luv hear netcollex p msg repli stop',
#  'ummma call check life begin qatar pl pray hard',
#  'delet contact',
#  'sindu job birla soft',
#  'wine flow never',
#  'thk co plaza mah',
#  'ur typic repli',
#  'request mell mell oru minnaminungint nurungu vettam set callertun caller press copi friend callertun',
#  'dirt floor window shirt open mouth flow dream world half chore time joy lot tv show guess thing exist rain hail mist time',
#  'aaooooright work',
#  'leav hous',
#  'love interview today happi boy miss',
#  'custom servic annonc year deliveri wait call arrang deliveri',
#  'winner special select receiv cash holiday flight speak live oper claim',
#  'safe miss envi real life',
#  'car hous parent job hand',
#  'love excit day spend make happi',
#  'pl stop bootydeli f invit friend repli www sm ac bootydeli stop send stop frnd',
#  'bangbab ur order receiv servic msg download ur content goto wap bangb tv ur mobil internet servic menu',
#  'place ur point cultur modul',
#  'urgent contact weekend draw show prize guarante call claim code valid hr',
#  'frnd avoid missunderstd wit belov',
#  'great escap fanci bridg lager tomo',
#  'complet form clark utter wast',
#  'sir axi bank account bank address',
#  'hmmm thk time hop ard free abt muz call discuss liao',
#  'time come',
#  'bloodi hell believ forgot surnam mr give clue spanish begin',
#  'gonna finish bath fine night',
#  'money carlo make call',
#  'mall',
#  'turn friend stay show back lt gt feel free ahead smoke lt gt worth',
#  'text repli',
#  'spoke maneesha satisfi experi repli toll free',
#  'lift hope offer money especi month approach hurt studi gr weekend',
#  'trust',
#  'gentleman treat digniti respect',
#  'guy close',
#  'great bye',
#  'handsom find job lazi work back net mummi boytoy miss',
#  'haha awesom minut',
#  'call custom servic repres freephon pm guarante cash prize',
#  'xma radio time',
#  'ju reach home bath si net finish',
#  'uniqu find august www areyouuniqu co uk',
#  'sorri join leagu touch great deal friend time great person cost great week',
#  'final complet cours',
#  'stop suggest stay give or stool',
#  'hope settl school year wishin gr day',
#  'gud mrng dear hav nice day',
#  'person stori',
#  'hamster dead hey tmr meet pm orchard mrt',
#  'kate even hope tomorrow bit bloodi babyjontet txt back xxx',
#  'found enc lt gt',
#  'lt gt buck',
#  'darlin ive finish colleg txt finish love kate xxx',
#  'account refil success inr lt decim gt keralacircl prepaid account balanc rs lt decim gt transact id kr lt gt',
#  'goodmorn sleep',
#  'call alter',
#  'dun buy ericsson oso oredi lar',
#  'enter cabin happi b day boss felt special askd lunch lunch invit apart',
#  'aight dat straight dogg',
#  'give connect today lt decim gt refund bill',
#  'shoot big load readi',
#  'bruv hope great break reward semest',
#  'home chat',
#  'studi',
#  'leh',
#  'sound great home',
#  'final match head draw predict',
#  'tire slept past night',
#  'easi select mean',
#  'exam march',
#  'gt atm regist readi',
#  'prob ur time',
#  'call ubandu run instal hard disk copi import file system give repair shop',
#  'sorri call',
#  'leh cours happen lar romant ju bit thk nite sceneri nice leh',
#  'mobil txt nokia collect today www tc optout gbp mtmsg',
#  'appreci call talk',
#  'meet ur dream partner ur career flyng start find free txt horo ur star sign g horo ari',
#  'hey compani elama mudyadhu',
#  'life strict teacher bcoz teacher teach lesson amp conduct exam life conduct exam amp teach lesson happi morn',
#  'dear morn',
#  'gandhipuram walk cross cut road side lt gt street road turn',
#  'dear rubber place',
#  'sorri batteri die',
#  'tv avail work place',
#  'text meet sexi today find date flirt join p repli age sam msg recd thirtyeight penc',
#  'print lt gt upstair',
#  'closer bu stop street',
#  'reach',
#  'theori argument win situat lose person argu ur friend kick amp correct',
#  'secret admir make contact find r reveal think ur special call',
#  'tomarrow final hear laptop case',
#  'pleassssssseeeee tel avent sportsx',
#  'shine meant sign sound',
#  'told baig watch watch gave co fr today touch',
#  'rememb commerci',
#  'late websit slipper',
#  'ask call',
#  'kalli inning',
#  'work goodnight fix readi time wake dearli miss night sleep',
#  'congratul ur award cd voucher gift guarante free entri wkli draw txt music tnc www ldew win ppmx age',
#  'ranjith cal drpd deeraj deepak hold',
#  'wen ur lovabl bcum angri wid dnt coz angri childish show deep affect luv kettoda manda nice day',
#  '',
#  'up day ship compani take wk usp take week lag bribe nipost stuff',
#  'back lemm readi',
#  'necessarili expect back headin',
#  'mmm yummi babe nice jolt suzi',
#  'lover',
#  'contact repli offer video handset anytim network min unlimit text camcord repli call',
#  'park mini come today',
#  '',
#  'shop co si dun disturb liao',
#  'luton ring ur',
#  'hey horni chat nake text hot text charg pm unsubscrib text stop',
#  'dint',
#  'wana plan trip sometm',
#  'hold',
#  'ur rington servic chang free credit club mobil choos content stop txt club stop p wk club box mk wt',
#  'evo download flash jealou',
#  'rington club uk singl chart mobil week choos top qualiti rington messag free charg',
#  'sort narcot situat',
#  'night end day morn special smile sunni ray leav worri blue blue bay',
#  'hmv bonu special pound genuin hmv voucher answer easi question play send hmv info www percent real',
#  'usf guess car',
#  'object bf come',
#  '',
#  'rob mack gf theater',
#  'awesom bit',
#  'type food',
#  'hand celebr full swing',
#  'call tool',
#  'wen miss person definit special person special miss touch gdeve',
#  'ask money',
#  'oki',
#  'usual guy pass night ahold throw',
#  'tonight class let earli',
#  '',
#  'babi cruisin girl friend r give call hour home alright fone fone love jenni xxx',
#  'life mean lot love life love life world call friend call world',
#  'dear mail tonit busi street updat tonit thing varunnathu edukkukaye raksha ollu real',
#  'hey told gautham',
#  'haf found feel stupid work',
#  'oop bit',
#  'buzi',
#  'accident delet messag resend',
#  'mobil custom claim free camera phone upgrad pay sim card loyalti call offer end thfeb appli',
#  'situat gurl appropri',
#  'hurt teas make cri life plz rose grave stupid miss nice day bslvyl',
#  'pick phone pl send messag',
#  'coffe run tomo believ time week',
#  'awesom rememb time high time diesel',
#  'shit shock scari imagin def night crash night save taxi',
#  'food fridg meal tonight',
#  'womdarful actor',
#  'sm ac blind date rodd aberdeen unit kingdom check http img sm ac w icmb cktz r blind date send hide',
#  'remb book',
#  'wana meet',
#  'friendship hang thread buy stuff',
#  'themob check newest select content game tone gossip babe sport mobil fit funki text wap',
#  'garag key bookshelf',
#  'today accept day accept brother sister lover dear clo lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rpli mean enemi',
#  'ur smart win week weekli quiz text play cs winnersclub box uz gbp week',
#  'give call friend money definit buy week',
#  'day normal real ur uniqu hope rest mylif hope find wot lost',
#  'made day great day',
#  'advanc happi pongal',
#  'hmmm guess kb power yoga haha dunno tahan power yoga anot thk oso forgot liao',
#  'friend afraid',
#  'decemb mobil mth entitl updat latest colour camera mobil free call mobil updat co free',
#  'coffe cake guess',
#  'merri christma babe love kiss',
#  'hey watch x lunch haha',
#  'cud ppl gona b bit co buse hav gon past co full waitin x',
#  'great guild meet bristol road touch weekend plan flight week',
#  'problem',
#  'call messag miss call',
#  'today class',
#  'sign track record read women',
#  'cool text park',
#  'read text meant joke read light',
#  'movi',
#  'book tomo return immedi',
#  'call germani penc minut call fix line access number prepay direct access',
#  'chanc evapor violat privaci steal phone number employ paperwork cool contact report supervisor',
#  'valentin day special win quiz partner trip lifetim send p msg rcvd custcar',
#  'daaaaa home babe',
#  'cool wine dine',
#  'sleep surf',
#  'sorri call',
#  'call call hand phone',
#  'great lot',
#  'post text happi read wiv carolin favourit bless',
#  'hide stranger',
#  'interest',
#  'sister clear round birla soft yesterday',
#  'gudnit tc practic',
#  'di yiju ju ur mail case huim di',
#  'small prestig problem',
#  'fanci shag interest sextextuk txt xxuk suzi txt cost msg tnc websit x',
#  'check miss jeremiah great month',
#  'iphon',
#  'car hour half apeshit',
#  'today sorri day angri misbehav hurt plz plz slap urself bcoz ur fault basic',
#  'guy figur alcohol jay figur safe spend weed',
#  'lt gt ish minut minut ago wtf',
#  'call forgot happi onam sirji fine rememb insur person meet qatar insha allah rakhesh tata aig join tissco tayseer',
#  'congratul ur award cd voucher gift guarante free entri wkli draw txt music tnc www ldew win ppmx age',
#  'ur cash balanc current pound maxim ur cash send cash p msg cc hg suit land row w hl',
#  'actor work work even sleep late unemploy moment sleep late unemploy day saturday',
#  'st andrew boy long cold post',
#  'cool cool chikku chikku db',
#  'prob',
#  'check audrey statu',
#  'busi finish year forward final meet',
#  'afternoon sunshin dawn day refresh happi aliv breath air smile love',
#  'worri',
#  'updat xma offer latest motorola sonyericsson nokia free bluetooth doubl min txt orang call mobileupd call optout f',
#  'discount code rp stop messag repli stop www regalportfolio co uk custom servic',
#  'uniform',
#  'cool text readi',
#  'boytoy geeee miss woke wish bed cuddl love',
#  'spoil bed',
#  'bath msg lt gt',
#  'talk pay agre price pl buy pay',
#  'rington order refer charg gbp week unsubscrib anytim call custom servic',
#  'happen',
#  'recognis',
#  'lot thing happen lindsay year sigh bar ptbo blue heron',
#  'payasam rinu bring',
#  'taught ranjith sir call sm becau he verifi project prabu told today mistak',
#  'guess worri bodi repair worri slow test guid ovul relax reason worri followin',
#  'give coupl minut track wallet',
#  'hey leav big deal',
#  'hey late meet',
#  'doubl min txt month free bluetooth orang avail soni nokia motorola phone call mobileupd call optout dx',
#  'mr owl lick',
#  'custom place call',
#  'mm time fun',
#  'mth half price orang line rental latest camera phone free phone mth call mobilesdirect free updat stoptxt',
#  'lunch buffet eat',
#  'late fr dinner',
#  'hey sat intro pilat kickbox',
#  'morn',
#  'offic room day shut',
#  'pick bout ish time',
#  'perform award calcul month current month period',
#  'sleep call back text gr rock si send text wen wake',
#  'put busi put pictur ass facebook open pictur room hurt make feel violat',
#  'even sir salam wahleykkum share happi news grace god offer tayseer tissco join hope fine inshah allah meet rakhesh visitor india',
#  'hmmm chang field quickli wanna system administr network administr',
#  'free rington text poli text st free tone x pw txt stop',
#  'dear chechi talk',
#  'hair cream ship',
#  'happen',
#  'yep great loxahatche xma tree burn lt gt start hour',
#  'haha drive usf lot stoner',
#  'slightli disastr class pm fav darl hope day coffe wld stay late tomorrow time place',
#  'week fanci drink',
#  'headin busetop',
#  'messag text miss sender miss number miss date miss miss lot miss fullonsm',
#  'room point iron plan weekend',
#  'co',
#  'oki yan jiu skip ard oso mrt blah blah blah',
#  'bring home wendi',
#  'date servic cal box sk ch',
#  'whatsup sleep',
#  'alright goal',
#  'free entri weekli competit text word win www txttowin co uk',
#  'alright head minut text meet',
#  'send logo ur lover name join heart txt love mobno love adam eve yahoo pobox w wq txtno ad p',
#  'week take live call',
#  'contact date servic enter phone fanci find call landlin pobox tf p',
#  'siva hostel aha',
#  'urgent mobil number award prize guarante call land line claim valid hr',
#  'send ur friend receiv ur voic speak express childish naughti sentiment rowdi ful attitud romant shi attract funni lt gt irrit lt gt lovabl repli',
#  'guess',
#  'aathi dear',
#  'pain urin',
#  'esplanad mind give lift co car today',
#  'wnt buy bmw car urgent vri urgent hv shortag lt gt lac sourc arng di amt lt gt lac prob',
#  'home watch tv',
#  'fifteen fuck minut respond question',
#  'congrat nokia video camera phone call call cost ppm ave call min vari mobil close post bcm ldn wc xx',
#  'book ticket pongal',
#  'avail hillsborough amp lt gt',
#  'messag askin lt gt dollar shoul pay lt gt lt gt',
#  'g iouri told stori ten time',
#  'long applebe fuck',
#  'hope txt journey gd min late',
#  'love arrang',
#  'great bhaji told kalli cricket sachin world tough',
#  'suppos wake gt',
#  'oic found group liao',
#  'sorri call',
#  'hey hey wereth monkeespeopl monkeyaround howdi gorgeou howu doin foundurself jobyet sausag love jen xxx',
#  'sorri batteri die gram place',
#  'blimey exercis kinda rememb wot',
#  'concentr dear mind',
#  'made plan year',
#  '',
#  'hank lotsli',
#  'hope day today',
#  'detail transfer acc',
#  'stay tough optimist thing improv month',
#  'loan purpos homeown tenant welcom previous refus call free text back',
#  'make oreo truffl',
#  'ami ure beauti intellig woman lot worri',
#  'hope result consist intellig kind start practicum link ear open ttyl',
#  'call cost guess miss love',
#  'differ feel waver decis cope individu time heal believ',
#  'phone gonna stay',
#  'great day reason god',
#  'upgrdcentr orang custom claim free camera phone upgrad loyalti call offer end juli appli opt avail',
#  'sorri call bye',
#  'railway',
#  'great princess love give receiv oral doggi style fave posit enjoy make love lt gt time night',
#  'put stuff road slipperi',
#  'ride bike',
#  'ju wait rain stop',
#  'compani languag',
#  'okmail dear dave final notic collect tenerif holiday cash award call landlin tc sae box cw wx ppm',
#  'long scream princess',
#  'meant money enter account bank remov flat rate transfer lt gt account lt gt dollar remov bank differ charg differ trust person send account detail co',
#  'laid tonight real dog locat direct ur mob join uk largest dog network txting moan ec p msg p',
#  'nice line broken heart plz time infront wise trust',
#  'gonna head usf fifteen minut',
#  'love aathi love lot',
#  'tension machi problem',
#  'pick',
#  'guy back g stay mcr',
#  'sec',
#  'carlo friend work weekend',
#  'watch tv',
#  'babi wait tast real',
#  'chang fb jaykwon thuglyf falconerf',
#  'win side long time',
#  'free messag activ free text messag repli messag word free term condit visit www',
#  'dear reach railway happen',
#  'depend qualiti type boy fade glori ralph',
#  'fix send test messag',
#  'sorri account dri trade back half buy shit credit card',
#  'congrat year special cinema pass call suprman matrix starwar free bx ip pm miss',
#  'sorri meet call',
#  'class lt gt reunion',
#  'free call',
#  'meh',
#  'monday sorri repli late',
#  'told accentur confirm',
#  'kate jackson rec center ish',
#  'dear reach room',
#  'fight world easi win lose bt fightng close dificult lose lose win lose',
#  '',
#  'check nuerologist',
#  'lolnic fish water',
#  'congratul week competit draw prize claim call b cs stop sm ppm',
#  'wait car bore co wait home stuff watch tv',
#  'westshor hyde park villag place hous',
#  'anthoni bring money school fee pay rent stuff friend',
#  'signific',
#  'opinion jada kusruthi lovabl silent spl charact matur stylish simpl pl repli',
#  'latest g scroung ammo give ak',
#  'prabha soryda reali frm heart sori',
#  'forgiven',
#  'jst chang tat',
#  'guarante latest nokia phone gb ipod mp player prize txt word collect ibhltd ldnw p mtmsgrcvd',
#  'competit',
#  'boltblu tone p repli poli mono poli cha cha slide slow jamz toxic stop tone txt',
#  'credit top http www bubbletext renew pin tgxxrz',
#  'transport problemat sat night join bday feel free definit book fri',
#  'person unconsci children adult behav abnorm call',
#  'ebay',
#  'pickl',
#  'gonna taco',
#  'rude campu',
#  'urgent mobil award bonu caller prize attempt contact call box',
#  'b ard christma enjoy merri x',
#  'today offer claim ur worth discount voucher text savamob member offer mobil cs unsub repli x',
#  'pretti ladi singl',
#  'reciev hr term condit channel teletext pg',
#  'jay doubl faggot',
#  'privat account statement show redeem point call identifi code expir',
#  'today sunday sunday holiday work',
#  'gudnit tc practic',
#  'late',
#  'call hope r malaria miss guy miss big pl give love especi great day',
#  'afternoon love day hope lead job boytoy send passion kiss',
#  'probabl gonna tonight lt',
#  'fat finger press button',
#  'ummmmmaah happi return day dear sweet heart happi birthday dear',
#  'tirupur start offic call',
#  'www applausestor monthlysubscript p msg max month csc web age stop txt stop',
#  'famou quot develop abil listen uncondit lose temper confid mean marri',
#  'colleg',
#  'oclock bash flat plan',
#  'girl stay bed girl recoveri time id pass fun coop bed',
#  'special',
#  'invit apologis cali sweet english bloke weddin',
#  'sorri long omw',
#  'wait lt gt',
#  'give minut alibi cut hair time',
#  'imagin final sink bath put pace eat left imagin feel cage cock surround bath water remind own enjoy cuck',
#  'hurri weed defici day',
#  'acknowledg astoundingli tactless gener faggi demand blood oath fo',
#  'night warm bath drink cup milk work magic loos weight',
#  'fri pan case cheap book silli fri pan book',
#  'uv mutat sunscreen essenti theseday',
#  'lunch onlin',
#  'friend told',
#  'princess pic pretti',
#  'aiyo dunno abt repli time repli fast lucki workin bao ur sugardad gee',
#  'msg offic',
#  'browni nice',
#  'geeeee love bare stand',
#  'gent contact weekend draw show prize guarante call claim code valid hr ppm',
#  'fuck babe miss send money net crave',
#  'call mrw ninish address icki american freek stop callin jen',
#  'oooh bed ridden ey',
#  'gym love smile hope day babe miss',
#  'love daddi make scream pleasur slap ass dick',
#  'wot wanna missi',
#  'yar wait mum finish sch lunch morn stay home clean room room clean hee',
#  'lab goggl',
#  'open',
#  'wait call',
#  'wait sch daddi',
#  'cash prize claim call',
#  'tire argu week week',
#  'wait sch finish ard',
#  'mobil number claim call back ring claim hot line',
#  'arngd marriag r walkin unfortuntli snake bite bt love marriag danc frnt snake amp sayin bite bite',
#  'earli dinner izzit',
#  'chang',
#  'contact repli offer min textand video phone call repli free deliveri tomorrow',
#  'wife kid kid day',
#  'scotland hope show jjc tendenc live dream',
#  'headach hour sick time',
#  'dun thk quit hmmm jazz yogasana oso meet lesson',
#  'ring meiv gotani credit',
#  'srsli yi',
#  'meet call',
#  'ur chanc win wkli shop spree txt shop www txt shop custcar x p wk',
#  'special select receiv pound award call line close cost ppm cs appli ag promo',
#  'privat account statement show redeem point call identifi code expir',
#  'grand prix',
#  'stranger choos friend long world stand friendship end let friend forev gud nitz',
#  'great',
#  'gud mrng dear nice day',
#  'import custom servic announc call freephon',
#  'exhaust train morn wine pie sleep',
#  'buy mum present',
#  'mind blastin tsunami occur rajnik stop swim indian ocean',
#  'send home readi',
#  'speak cash',
#  'happi noon',
#  'meet lunch',
#  '',
#  'xclusiv clubsaisai morow soire special zouk nichol pari free rose ladi info',
#  'meant wait bore bridgwat banter',
#  'neva mind',
#  'fine imma drink somethin find',
#  'day kick euro date latest news result daili remov send txt stop',
#  'valentin game send di msg ur friend answer r love que colour suit rpli',
#  'depend',
#  'today cer nice catch ave find time',
#  'call choos futur',
#  'happi valentin day earli hundr handsom beauti wish finish aunti uncl st',
#  'shock leh co tell shuhui tell leona liao abt ur reaction',
#  'famili happi',
#  'pick immedi aft ur lesson',
#  'snow snow kind weather bring ppl friendship grow',
#  'dear lt gt dollar',
#  'word word leav dismay time',
#  'make alex birthday fifteen minut concern',
#  'sorri thing pub',
#  'straight bring bud drink straight cash',
#  'haha hear offici paid market',
#  'lick center tootsi pop',
#  'thk r teacher make longer darren cut short',
#  'textbuddi chat horni guy ur area p free receiv search postcod gaytextbuddi txt',
#  'today vodafon number end select receiv award number match call receiv award',
#  '',
#  '',
#  'forward messag send',
#  'seventeen pound hundr ml hope',
#  'dear voucher holder claim week offer pc http www tlp co uk expressoff ts cs appli stop text txt stop',
#  'funni',
#  'sweetheart hope kind day load reason smile biola',
#  'login time dad fetch home',
#  'shower babi',
#  'askd question hour answer',
#  'imma definit restock thanksgiv',
#  'kiss kiss sound effect gorgeou kind person smile brighten day',
#  'probabl gonna swing wee bit',
#  'nice readi thursday',
#  'brave buse train triumph b jolli rest week',
#  'watch cartoon listen music amp eve templ amp church',
#  'mind happen uncomfort',
#  'privat account statement show redeem point call identifi code expir',
#  'prob send email',
#  'cash prize claim call rstm sw ss ppm',
#  'cool slow gentl sonetim rough hard',
#  'gonna sorri normal start panic time sorri tuesday',
#  'wait wesley town bet hella drug',
#  'fine miss',
#  'person stori',
#  'dealer impati',
#  'sun earth send luv ray cloud river send luv rain meet send msg gud evng',
#  'place',
#  'make free wikipedia',
#  'premium phone servic call',
#  'lay rock rock envelop envelop paper paper word',
#  'mum repent',
#  'sorri home daddi fetch',
#  'leav start prepar',
#  'babi studi posit kama sutra',
#  'chikku nang bakra msg kalstiya tea coffe',
#  'carlo minut buy',
#  'pay lt decim gt lakh',
#  'even ttyl',
#  'receiv msg',
#  'big belli laugh tomo',
#  'sm ac sun post cool want stop send stop',
#  'ur st rington free repli msg gr top tone phone week wk opt send stop',
#  'ditto worri anymor night peac',
#  'lt gt pick',
#  'knw drink milk',
#  'find card great escap wetherspoon',
#  'piggi r awak bet sleep lunch',
#  'freaki',
#  'miss call yell scrappi miss wait home lone today',
#  'hex place talk explain',
#  'sdryb',
#  'xy lunch',
#  'year work lapdanc love sex text live bedroom text textoper g ppmsg',
#  'want wait finish lect co lect finish hour',
#  'finish work',
#  'king cri babi great build map imprtant r today reach tomorw gud',
#  'dear cherthala case r come cochin pl call bfore start reach day r come tmorow engag holiday',
#  'love torch bold',
#  'forward call immedi urgent messag wait',
#  'farm open',
#  'sorri troubl buy dad big small sat sun',
#  'sister law hope great month hey abiola',
#  'purchas stuff today mail box number',
#  'poop prob send laptop fix cuz gpu problem',
#  'job entrepreneur',
#  'aight close alex place',
#  'meet corpor st gap mind work',
#  'mum buy food home',
#  'msg repli msg',
#  'r pay',
#  'sorri call',
#  'import prevent dehydr give fluid',
#  'bit weird suppos happen idea pub',
#  'dear sat pray even felt sm time',
#  'away trek long famili town sorri',
#  'wanna gym harri',
#  'late lar ard wun b drivin',
#  'review fantast nokia gage game deck club nokia www cnupdat newslett unsubscrib alert repli word',
#  'mth half price orang line rental latest camera phone free phone mth call mobilesdirect free updat stoptxt cs',
#  'height confid aeronaut professor wer calld amp wer askd aeroplan aftr sat wer told plane ws made student dey hurri plane bt move made student start datz confid',
#  'weird time night g smoke day shitstorm attribut come make smoke',
#  'pm cost p',
#  'save stress person dorm account send account detail money',
#  'lunch menu',
#  'stuff sell',
#  'urgent attempt contact call b csbcm wc xx callcost ppm mobilesvari max',
#  'book lesson msg call work sth spec membership px',
#  'guarante cash prize claim yr prize call custom servic repres pm',
#  'macha feel upset assum mindset believ even wonder plan life begin call anytim',
#  'send address',
#  'fine anytim',
#  'wondar full flim',
#  'cooki jelli',
#  'world run feel admit mad correct call life run world r run let run',
#  'scrumptiou daddi eat night long',
#  'co lar dao pm fri today',
#  'alright omw gotta chang order half',
#  'jide studi visit',
#  'dunno',
#  'email alertfrom jeri stewarts kbsubject low cost prescripiton drvgsto listen email call',
#  'spring come earli yay',
#  'feel money steak dinner',
#  'troubl convinc tel tel neglect msg read repli',
#  'leav qatar tonit search opportun fast pl add ur prayer dear rakhesh',
#  'talk',
#  'appreci',
#  'custom loyalti offer nokia mobil txtauction txt word start ctxt tc p mtmsg',
#  'wish',
#  'haha mayb rite feel gd faster find gal group attach liao',
#  'glad made',
#  'time time ahead',
#  'room put clock back shout realis wahay hour bed',
#  'free gym',
#  'shorter ladi gaze eye',
#  'dunno ju lido time',
#  'promis princess run send pic chanc ttyl',
#  'subscrib mobil content servic uk day send stop helplin',
#  'reason spoken year great week exam',
#  'monday week give full gist',
#  'realiz year thousand ladi run tattoo',
#  'import custom servic announc premier',
#  'gimm lip caveboy',
#  'librari',
#  'reali sorri recognis number confus r',
#  'holla',
#  'spare room top head',
#  'faith make thing possibl hope make thing work love make thing beauti christma merri christma',
#  'made appoint',
#  'call carlo phone vibrat act hear text',
#  'romant pari night flight book year call ts cs appli',
#  'grandma dear felt shit morn hungov night leav sat',
#  'urgent ur guarante award unclaim call closingd claimcod pmmorefrommobil bremov mobypobox ls yf',
#  'ju co gua mt faber yest yest ju mah today ju call',
#  'wish famili merri x happi year advanc',
#  'ur award citi break win summer shop spree wk txt store skilgm tsc winawk age perwksub',
#  'nt goin somethin meetin dinner haha wonder ti time',
#  'sorri call',
#  'pick phone pl send messag',
#  'dramat school close tomorrow appar drive inch snow suppos',
#  'damn job hunt',
#  'drunkard hair moment tonight wat plan',
#  'idc weasel shit row',
#  'lt gt minut space',
#  'sleep surf',
#  'pick trash',
#  'friend live smoke spend hour beg smoke',
#  'kate love tonight phone tomorrow sing guy gave card xxx',
#  'happi year dear brother miss number decid send text wish happi abiola',
#  'mean',
#  'opinion jada kusruthi lovabl silent spl charact matur stylish simpl pl repli',
#  'hmmm hour slave late punish',
#  'beerag',
#  'import custom servic announc premier call freephon',
#  'turn randomlli open',
#  'suppos make town',
#  'time fix spell complet diff word figur',
#  'live life perfect partner txt back age join mobil commun p sm',
#  'free top polyphon tone call nation rate toppoli week text subpoli pole unsub',
#  'gud mrng dear hav nice day',
#  'hope enjoy game yesterday sorri touch pl fondli bein thot great week abiola',
#  'ur drive tmr',
#  'dogbreath sound jan',
#  'omg scream weigh lost weight woohoo',
#  'gener uncount noun dictionari piec research',
#  'hang',
#  'orang custom claim free camera phone upgrad loyalti call offer end thmarch appli opt availa',
#  'petey boy wherear friendsar thekingshead canlov nic',
#  'msg b leav hous',
#  'gimm lt gt minut ago',
#  'chanc claim ur worth discount voucher today text shop savamob offer mobil cs savamob pobox uz',
#  'appt lt time gt fault listen told',
#  'free st week nokia ur mobil week txt nokia txting ur mate www getz co uk pobox w wq norm p',
#  'guarante award cashto claim ur award call free stop getstop php rg jx',
#  '',
#  'dled imp',
#  'make smokin',
#  'boooo work quit',
#  'take half day leav bec',
#  'ugh wanna bed warm',
#  'nervou lt gt',
#  'ring guy costum gift futur yowif hint hint',
#  'congratul ur award cd gift voucher free entri weekli draw txt music tnc www ldew win ppmx age',
#  'borrow ur bag',
#  'outbid simonwatson shinco dvd plyr bid visit sm ac smsreward bid notif repli',
#  'boytoy miss happen',
#  'lot babe model youi bring match',
#  'bring galileo dobbi',
#  'respond',
#  'boo babe enjoyin yourjob b gettin hunni hope ure llspeak soonlot lovem xxxx',
#  'afternoon starshin boytoy crave ach fuck sip cappuccino miss babe teas kiss',
#  'road txt',
#  'smsservic yourinclus text credit pl goto www comuk net login qxj unsubscrib stop extra charg comuk cm ae',
#  'p alfi moon children song ur mob ur txt chariti nokia poli chariti poli zed profit chariti',
#  'even ttyl',
#  'bit piec sigh',
#  'hahaha brain dear',
#  'hey mail',
#  'sorri light turn green meant friend want lt gt worth',
#  'yesterday sir wonder hope enjoy burial mojibiola',
#  'secret admir reveal think r special call opt repli reveal stop msg recd cust',
#  'mate rv hav nice hol messag coz age start drive stay road rvx',
#  'dear voucher holder claim week offer pc http www tlp co uk expressoff ts cs appli stop text txt stop',
#  'skype wit kz sura pleasur compani hope ultimatum countin aburo enjoy messag day ago',
#  'sure result offer',
#  'morn dear great amp success day',
#  'anytim network min text video phone pound week call repli deliveri tomorrow',
#  'sir late pay rent past month pay lt gt charg felt inconsider nag give great cost speak recess pay charg month askin ahead month',
#  'contact offer video phone anytim network min half price rental camcord call repli deliveri wed',
#  'chanc claim ur worth discount voucher text savamob member offer mobil cs remov txt x stop',
#  'luv soo understand special r ring morrow luv xxx',
#  'pl send comprehens mail pay',
#  'prashanthettan mother pass away night pray famili',
#  'urgent call landlin complimentari ibiza holiday cash await collect sae cs box sk wp ppm',
#  '',
#  'shit suit xavier decid give lt gt second warn samantha come play jay guitar impress shit doug realiz live anymor',
#  'stomach trauma swear eat lose weight',
#  'offic what matter msg call break',
#  'bare room x fuck shoe sorri',
#  'today offer claim ur worth discount voucher text savamob member offer mobil cs unsub repli x',
#  'reach orchard wan buy ticket',
#  'real babi bring tigress',
#  'run activ full version',
#  'poor babi hope urfeel bettersn luv probthat overdos work hey care spk sn lot lovejen xxx',
#  'stop stori told return order',
#  'talk sexi make friend fall love world discreet text date servic text vip meet',
#  'babe',
#  'ana tomarrow come morn lt decim gt sathi rto offic repli home',
#  'spoon',
#  'name tampa',
#  'work',
#  'brother geniu',
#  'sorri guess hold connect hour text',
#  'find time bu coz sort stuff',
#  'ive lotta corvett',
#  'congratul ur award yr suppli cd virgin record mysteri gift guarante call ts cs www smsco net pm approx min',
#  'consid wall bunker shit import play peac guess place high matter',
#  'privat account statement xxxxxx show redeem point call identifi code expir',
#  'posh bird chap user trial prod champney put address dob asap r',
#  'xma free text messag video phone half price line rental call free find',
#  'offici philosoph hole wanna call home readi save',
#  'problem experi understand american custom voic',
#  'text drop x',
#  'ugh long day exhaust cuddl nap',
#  'talk atleast day miss friend world shakespear shesil lt gt',
#  'shop drop cash travel voucher call ntt box cr bt fixedlin cost ppm mobil vari',
#  'castor',
#  'sunshin quiz wkli win top soni dvd player countri liverpool play mid week txt ansr sp tyron',
#  'secret admir make contact find r reveal think ur special call',
#  'secret admir make contact find r reveal think ur special call stopsm',
#  'remind download content paid goto http doit mymobi tv collect content',
#  'knew give break time woul lead want miss curfew gonna gibe midnight movi gonna home getsleep b studdi ear train',
#  'love give massag lot babi oil fave posit',
#  '',
#  'yoyyooo chang permiss drive mac usb flash drive',
#  'gibb unsold mike hussey',
#  'talk',
#  'dun cut short leh dun fail sad',
#  'unbeliev faglord',
#  'wife knew time murder',
#  'princess',
#  'great princess',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg',
#  'busi bore msg oso dunno colour choos',
#  'g class earli tomorrow smoke lt gt',
#  'superb grate mean opportun happier tomorrow today',
#  'hope week check',
#  'hope agent drop book thing year boston nyc experi',
#  'thursday night work',
#  'free rington wait collect simpli text password mix verifi usher britney fml box mk ppw',
#  'probabl money worri thing come due outstand invoic work month ago',
#  'possibl teach',
#  'wonder phone batteri dead love babe',
#  'love smell bu tobacco',
#  'worri derek taylor assum worst',
#  'hey charl sorri late repli',
#  'lastest stereophon marley dizze racal libertin stroke win nookii game flirt click themob wap bookmark text wap',
#  'give grinul greet speak',
#  'white fudg oreo store',
#  'januari male hot gay chat cheaper call nation rate p cheap p peak stop text call p',
#  'love long leav zaher word ym happi sad left miss',
#  'sorri hurt',
#  'feel nauseou piss eat sweet week today plan pig diet week hungri',
#  'earli project meet',
#  'call wait call',
#  'carlo chip',
#  'send remind today wonder weekend',
#  'msg iam addict msging wrong bcoz iam addict sweet friend bslvyl',
#  'hey gave photo regist drive tmr wanna meet yck',
#  'talk word',
#  'wana',
#  'school pl send ashley number',
#  'fine avalarr hollalat',
#  'attend round today reach home',
#  'delet websit blog magicalsong blogspot',
#  'wait chikku send aftr lt gt min',
#  'diet slice pizza yesterday ugh diet',
#  'give kvb acc detail',
#  '',
#  'money r lucki winner claim prize text money million give away ppt x normal text rate box w jy',
#  'sorri b friday hope find altern hope yr term',
#  'congratul ore mo owo wa enjoy wish happi moment fro',
#  'samu shoulder',
#  'time campu',
#  'dear matthew call landlin complimentari lux tenerif holiday cash await collect ppm sae cs box sk xh',
#  'dun wear jean',
#  'side fever vomitin',
#  'colleg',
#  'urgent call landlin complimentari tenerif holiday cash await collect sae cs box hp yf ppm',
#  'made friday stuf pig yesterday feel bleh writh pain kind bleh',
#  'sell coin sell coin paypal voila money back life pocket',
#  'theyr lot place hospit medic place safe',
#  'touch folk wait compani txt back age opt enjoy commun p sm',
#  'sorta blown coupl time recent id text blue weed',
#  'score sopha secondari applic school appli research cost contact joke ogunrind school expens',
#  'wait photo',
#  'ur cash balanc current pound maxim ur cash send p msg cc box tcr w',
#  'hey book kb sat lesson sat night free meet confirm lodg',
#  'chk ur belovd ms dict',
#  'time',
#  'awesom lemm',
#  'shb b',
#  'beauti truth graviti read care heart feel light feel heavi leav night',
#  'rememb dobbi bowl car',
#  'filthi stori girl wait',
#  'sorri ur msg yar poor night tmr brand room sleep',
#  'love decis feel decid love life simpler magic',
#  'welp appar retir',
#  'sort code acc bank natwest repli confirm person',
#  '',
#  'sick time',
#  'urgent contact today draw show prize guarante call land line claim valid hr',
#  'watch cartoon listen music amp eve templ amp church',
#  'chad gymnast class wanna site christian class full',
#  'buzi',
#  'catch sell lt gt',
#  'night menu noon menu',
#  'back beauti necklac token heart give wife like give call wait',
#  'aptitud class',
#  'b sort hous',
#  'yar wan hors race today mah eat earlier chicken rice',
#  'haha awesom omw back',
#  'thk shop close',
#  'account number',
#  'send wrongli lar',
#  'hey crap nite borin boggi bore biatch wait nxt time ave',
#  'talk',
#  'hesit time weak notebook eat day chang day',
#  'hey pay salari lt gt',
#  'month chocol weed alcohol',
#  'start search job day great potenti talent',
#  'reckon town eightish walk carpark',
#  'congrat mobil g videophon r call videochat wid mate play java game dload polyph music nolin rentl',
#  'fuckin time fuck',
#  'guess drop',
#  'carlo lt gt minut',
#  'offic call lt gt',
#  'geeee miss fuck wait year love kiss',
#  'yun ubi wan call tomorrow call iren bu ubi cre ubi tech park ph st wkg day',
#  'ugh gotta drive back sd butt sore',
#  'juli',
#  'relax time day parti night home tomorrow ish',
#  'wan stripe skirt',
#  'xma stori peac xma msg love xma miracl jesu hav bless month ahead amp wish merri xma',
#  'number',
#  'chang escal',
#  'yetund class run water make pl',
#  'lot happen feel quiet beth aunt charli work lot helen mo',
#  'wait bu stop aft ur lect lar dun car back pick',
#  ...]

# %%
# Label Encoding our Output Variable

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(messages['Label'])

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
# Train, Test, Split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(corpus, y, test_size=0.25, random_state=33)

# %%
# creating our Bag Of Words Model
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=2500, ngram_range=(1,2))

# %%
X_train=cv.fit_transform(X_train).toarray()
X_test=cv.transform(X_test).toarray()

# %%
np.set_printoptions(edgeitems=30, linewidth=1000000, formatter=dict(float=lambda x:'%.3g'%x) )

# %%
cv.vocabulary_
# Out:
# {'ask': 98,
#  'call': 246,
#  'place': 1572,
#  'room': 1763,
#  'cheap': 347,
#  'friend': 804,
#  'order': 1510,
#  'gram': 888,
#  'lt': 1236,
#  'gt': 900,
#  'lt gt': 1238,
#  'princess': 1626,
#  'make': 1256,
#  'happi': 941,
#  'princess make': 1627,
#  'make happi': 1260,
#  'sura': 2051,
#  'sun': 2039,
#  'tv': 2220,
#  'month': 1377,
#  'ur': 2268,
#  'standard': 1979,
#  'network': 1438,
#  'charg': 340,
#  'activ': 14,
#  'net': 1435,
#  'st': 1974,
#  'term': 2104,
#  'pobox': 1586,
#  'uz': 2307,
#  'cost': 467,
#  'pobox uz': 1588,
#  'meet': 1295,
#  'work': 2427,
#  'tel': 2095,
#  'tomorrow': 2180,
#  'work tomorrow': 2431,
#  'april': 81,
#  'real': 1684,
#  'date': 528,
#  'today': 2163,
#  'give': 857,
#  'special': 1951,
#  'treat': 2203,
#  'secret': 1804,
#  'wish': 2406,
#  'buy': 236,
#  'insid': 1056,
#  'bedroom': 155,
#  'orchard': 1509,
#  'dad': 519,
#  'car': 302,
#  'dinner': 589,
#  'leh': 1167,
#  'free': 778,
#  'tonight': 2188,
#  'hey': 968,
#  'gave': 831,
#  'photo': 1553,
#  'regist': 1706,
#  'drive': 625,
#  'tmr': 2156,
#  'wanna': 2351,
#  'wait': 2339,
#  'bu': 227,
#  'pick': 1555,
#  'line': 1184,
#  'geeee': 842,
#  'miss': 1336,
#  'fuck': 817,
#  'year': 2485,
#  'love': 1217,
#  'kiss': 1124,
#  'geeee miss': 843,
#  'love kiss': 1223,
#  'felt': 727,
#  'convey': 458,
#  'reason': 1688,
#  'costa': 470,
#  'sol': 1925,
#  'holiday': 984,
#  'await': 118,
#  'collect': 406,
#  'toclaim': 2161,
#  'sae': 1777,
#  'tc': 2082,
#  'stockport': 1993,
#  'sk': 1888,
#  'xh': 2469,
#  'pm': 1582,
#  'max': 1284,
#  'min': 1321,
#  'costa sol': 471,
#  'sol holiday': 1926,
#  'holiday await': 985,
#  'await collect': 119,
#  'collect call': 407,
#  'call toclaim': 283,
#  'toclaim sae': 2162,
#  'sae tc': 1779,
#  'tc pobox': 2084,
#  'pobox stockport': 1587,
#  'stockport sk': 1994,
#  'sk xh': 1890,
#  'xh cost': 2470,
#  'cost pm': 468,
#  'pm max': 1585,
#  'max min': 1285,
#  'babe': 129,
#  'doin': 611,
#  'wot': 2440,
#  'nite': 1454,
#  'hey babe': 969,
#  'meet call': 1296,
#  'msg': 1399,
#  'iam': 1031,
#  'addict': 18,
#  'msging': 1408,
#  'wrong': 2449,
#  'bcoz': 150,
#  'sweet': 2059,
#  'bslvyl': 224,
#  'iam addict': 1032,
#  'sweet friend': 2061,
#  'bloodi': 182,
#  'hell': 966,
#  'believ': 161,
#  'forgot': 768,
#  'mr': 1395,
#  'begin': 160,
#  'choos': 363,
#  'gr': 886,
#  'tone': 2185,
#  'wk': 2413,
#  'servic': 1827,
#  'weekli': 2381,
#  'credit': 489,
#  'kick': 1114,
#  'back': 132,
#  'enjoy': 661,
#  'busi': 235,
#  'wif': 2396,
#  'person': 1540,
#  'children': 358,
#  'adult': 23,
#  'move': 1391,
#  'pub': 1643,
#  'great': 891,
#  'cud': 500,
#  'happen': 940,
#  'xy': 2479,
#  'smth': 1918,
#  'eat': 646,
#  'ugh': 2240,
#  'class': 380,
#  'final': 735,
#  'hear': 955,
#  'laptop': 1143,
#  'case': 313,
#  'close': 385,
#  'eye': 694,
#  'vava': 2314,
#  'play': 1575,
#  'umma': 2246,
#  'wonder': 2423,
#  'text': 2108,
#  'cool': 462,
#  'cover': 476,
#  'hot': 1007,
#  'joy': 1098,
#  'father': 710,
#  'john': 1092,
#  'hav': 950,
#  'iq': 1071,
#  'ti': 2137,
#  'question': 1651,
#  'answer': 70,
#  'joy father': 1099,
#  'sir': 1882,
#  'mail': 1255,
#  'sir wait': 1883,
#  'come': 415,
#  'time': 2142,
#  'rock': 1759,
#  'complet': 424,
#  'cours': 475,
#  'complet cours': 425,
#  'reach': 1675,
#  'sch': 1793,
#  'problem': 1639,
#  'str': 2012,
#  'txt': 2221,
#  'nokia': 1455,
#  'hit': 975,
#  'poli': 1593,
#  'wk free': 2414,
#  'wk txt': 2415,
#  'txt nokia': 2227,
#  'nokia poli': 1462,
#  'smoke': 1917,
#  'difficult': 583,
#  'leav': 1163,
#  'day': 530,
#  'train': 2199,
#  'receiv': 1691,
#  'act': 12,
#  'late': 1147,
#  'night': 1448,
#  'sleep': 1897,
#  'give call': 859,
#  'call tomorrow': 284,
#  'sleep night': 1898,
#  'night night': 1450,
#  'readi': 1682,
#  'hous': 1010,
#  'open': 1494,
#  'load': 1195,
#  'put': 1647,
#  'sign': 1871,
#  'user': 2304,
#  'show': 1859,
#  'number': 1474,
#  'pin': 1561,
#  'wow': 2441,
#  'airport': 44,
#  'rd': 1674,
#  'thk': 2128,
#  'bath': 144,
#  'away': 127,
#  'system': 2070,
#  'side': 1868,
#  'rememb': 1712,
#  'inch': 1047,
#  'pleasur': 1578,
#  'readi lt': 1683,
#  'gt inch': 903,
#  'privat': 1629,
#  'account': 9,
#  'statement': 1984,
#  'redeem': 1701,
#  'point': 1590,
#  'identifi': 1038,
#  'code': 396,
#  'expir': 690,
#  'privat account': 1630,
#  'account statement': 10,
#  'statement show': 1985,
#  'show redeem': 1862,
#  'redeem point': 1702,
#  'point call': 1591,
#  'call identifi': 261,
#  'identifi code': 1039,
#  'code expir': 397,
#  'respons': 1739,
#  'power': 1607,
#  'heart': 957,
#  'care': 307,
#  'gud': 920,
#  'swt': 2067,
#  'dream': 621,
#  'swt dream': 2068,
#  'garden': 829,
#  'summer': 2037,
#  'select': 1809,
#  'worth': 2438,
#  'saturday': 1786,
#  'stop': 1999,
#  'co': 391,
#  'uk': 2241,
#  'summer free': 2038,
#  'co uk': 394,
#  'thing': 2124,
#  'quick': 1652,
#  'fine': 742,
#  'start': 1982,
#  'week': 2372,
#  'stuff': 2021,
#  'easi': 643,
#  'guy': 925,
#  'fun': 821,
#  'guy fun': 926,
#  'relax': 1709,
#  'parti': 1527,
#  'home': 990,
#  'ish': 1073,
#  'sister': 1884,
#  'round': 1766,
#  'soft': 1924,
#  'yesterday': 2489,
#  'tast': 2078,
#  'fish': 751,
#  'gonna': 873,
#  'pain': 1519,
#  'ass': 103,
#  'possibl': 1601,
#  'app': 75,
#  'hour': 1009,
#  'sick': 1867,
#  'aiyo': 47,
#  'meh': 1300,
#  'feel': 720,
#  'gd': 840,
#  'ice': 1035,
#  'cream': 488,
#  'oso': 1514,
#  'wan': 2347,
#  'town': 2197,
#  'worri': 2435,
#  'finish': 745,
#  'march': 1269,
#  'bu stop': 228,
#  'math': 1280,
#  'high': 973,
#  'score': 1796,
#  'appli': 77,
#  'salari': 1781,
#  'life': 1176,
#  'easier': 645,
#  'talk': 2074,
#  'job': 1091,
#  'avail': 116,
#  'made': 1251,
#  'plan': 1573,
#  'def': 563,
#  'sat': 1783,
#  'pay': 1532,
#  'luv': 1247,
#  'boytoy': 212,
#  'send': 1813,
#  'tm': 2155,
#  'remind': 1713,
#  'love love': 1226,
#  'dare': 523,
#  'stupid': 2022,
#  'quit': 1653,
#  'xuhui': 2473,
#  'bore': 198,
#  'skype': 1895,
#  'wit': 2411,
#  'compani': 422,
#  'hope': 999,
#  'messag': 1310,
#  'ago': 38,
#  'day ago': 532,
#  'sexi': 1837,
#  'check': 350,
#  'befor': 158,
#  'check room': 351,
#  'befor activ': 159,
#  'suppos': 2050,
#  'discuss': 598,
#  'abt': 3,
#  'trip': 2205,
#  'told': 2175,
#  'afternoon': 34,
#  'lesson': 1170,
#  'menu': 1305,
#  'noon': 1465,
#  'long': 1206,
#  'repli': 1719,
#  'semest': 1812,
#  'phone': 1545,
#  'chat': 345,
#  'set': 1833,
#  'moro': 1386,
#  'xx': 2474,
#  'wa': 2338,
#  'christma': 366,
#  'hug': 1021,
#  'lik': 1181,
#  'cute': 515,
#  'lucki': 1241,
#  'hate': 949,
#  'eatin': 647,
#  'goin': 872,
#  'watch': 2357,
#  'liao': 1172,
#  'nice': 1443,
#  'haha': 929,
#  'swing': 2066,
#  'uncl': 2249,
#  'reward': 1749,
#  'attend': 109,
#  'appreci': 79,
#  'ard': 83,
#  'merri': 1306,
#  'insur': 1059,
#  'qatar': 1648,
#  'allah': 52,
#  'rakhesh': 1660,
#  'join': 1093,
#  'dear': 545,
#  'morn': 1381,
#  'contact': 444,
#  'pound': 1604,
#  'prize': 1631,
#  'claim': 370,
#  'bt': 225,
#  'nation': 1430,
#  'rate': 1667,
#  'time contact': 2144,
#  'contact pound': 449,
#  'pound prize': 1606,
#  'prize claim': 1634,
#  'claim easi': 373,
#  'easi call': 644,
#  'call bt': 249,
#  'bt nation': 226,
#  'nation rate': 1431,
#  'smile': 1911,
#  'troubl': 2206,
#  'rain': 1658,
#  'sum': 2036,
#  'hurt': 1026,
#  'love smile': 1227,
#  'bring': 218,
#  'ga': 825,
#  'tell': 2096,
#  'appar': 76,
#  'light': 1179,
#  'school': 1795,
#  'stay': 1987,
#  'weather': 2367,
#  'food': 763,
#  'social': 1921,
#  'support': 2049,
#  'import': 1044,
#  'marri': 1273,
#  'local': 1198,
#  'action': 13,
#  'match': 1276,
#  'stop txt': 2006,
#  'txt stop': 2230,
#  'lost': 1212,
#  'girl': 854,
#  'shit': 1847,
#  'mum': 1417,
#  'lookin': 1210,
#  'strong': 2018,
#  'plz': 1580,
#  'note': 1468,
#  'mobil': 1352,
#  'amp': 58,
#  'type': 2237,
#  'coz': 477,
#  'attempt': 106,
#  'sim': 1874,
#  'card': 305,
#  'motorola': 1389,
#  'verifi': 2315,
#  'call mobil': 269,
#  'gt lt': 907,
#  'nokia motorola': 1461,
#  'enter': 664,
#  'detail': 575,
#  'call claim': 251,
#  'claim prize': 376,
#  'ur mobil': 2288,
#  'fight': 730,
#  'world': 2433,
#  'win': 2400,
#  'lose': 1211,
#  'win lose': 2402,
#  'probabl': 1638,
#  'earli': 639,
#  'earli tomorrow': 640,
#  'winner': 2405,
#  'cash': 314,
#  'award': 121,
#  'speak': 1949,
#  'live': 1191,
#  'oper': 1495,
#  'special select': 1955,
#  'select receiv': 1810,
#  'receiv cash': 1693,
#  'cash award': 316,
#  'speak live': 1950,
#  'live oper': 1193,
#  'oper claim': 1496,
#  'claim call': 371,
#  'pm cost': 1583,
#  'remain': 1711,
#  'test': 2107,
#  'dunno': 636,
#  'awak': 120,
#  'opinion': 1498,
#  'digit': 584,
#  'camera': 293,
#  'auction': 110,
#  'part': 1526,
#  'tcr': 2085,
#  'nokia free': 1458,
#  'digit camera': 585,
#  'free auction': 779,
#  'auction part': 111,
#  'send nokia': 1819,
#  'sound': 1941,
#  'lot': 1213,
#  'spent': 1962,
#  'boy': 211,
#  'grin': 897,
#  'frm': 812,
#  'wat': 2356,
#  'matter': 1281,
#  'assum': 104,
#  'phone phone': 1551,
#  'urgent': 2298,
#  'bonu': 192,
#  'caller': 286,
#  'urgent mobil': 2301,
#  'mobil award': 1353,
#  'award bonu': 122,
#  'bonu caller': 193,
#  'caller prize': 288,
#  'final attempt': 736,
#  'attempt contact': 107,
#  'contact call': 445,
#  'custom': 508,
#  'repres': 1732,
#  'guarante': 915,
#  'call custom': 252,
#  'custom servic': 513,
#  'servic repres': 1832,
#  'repres pm': 1733,
#  'pm guarante': 1584,
#  'guarante cash': 918,
#  'cash prize': 319,
#  'sort': 1940,
#  'internet': 1061,
#  'cancel': 299,
#  'visit': 2324,
#  'brand': 214,
#  'guess': 923,
#  'arrest': 92,
#  'aunt': 113,
#  'spring': 1971,
#  'crave': 486,
#  'pop': 1598,
#  'bout': 206,
#  'wen': 2386,
#  'chikku': 355,
#  'boston': 202,
#  'chang': 337,
#  'search': 1799,
#  'locat': 1199,
#  'nyc': 1481,
#  'cuz': 516,
#  'page': 1517,
#  'challeng': 333,
#  'chillin': 359,
#  'super': 2047,
#  'pl': 1565,
#  'find': 737,
#  'vomit': 2327,
#  'ring': 1752,
#  'mobil number': 1359,
#  'call back': 248,
#  'plenti': 1579,
#  'crazi': 487,
#  'mad': 1250,
#  'gbp': 836,
#  'free messag': 786,
#  'gbp week': 839,
#  'alright': 53,
#  'bit': 173,
#  'learn': 1162,
#  'latest': 1148,
#  'excit': 683,
#  'spend': 1961,
#  'doubl': 613,
#  'price': 1623,
#  'linerent': 1187,
#  'orang': 1505,
#  'bluetooth': 186,
#  'mobileupd': 1367,
#  'offer': 1482,
#  'optout': 1502,
#  'doubl min': 614,
#  'min doubl': 1322,
#  'doubl txt': 615,
#  'call mobileupd': 271,
#  'call optout': 275,
#  'church': 367,
#  'holla': 989,
#  'greet': 896,
#  'ron': 1762,
#  'fri': 801,
#  'reserv': 1737,
#  'half': 932,
#  'ur home': 2279,
#  'half hour': 933,
#  'usual': 2306,
#  'babi': 131,
#  'ive': 1077,
#  'want': 2352,
#  'piss': 1562,
#  'xxx': 2475,
#  'knw': 1127,
#  'di': 577,
#  'sm': 1906,
#  'id': 1036,
#  'ur mail': 2285,
#  'yar': 2483,
#  'honey': 995,
#  'boo': 195,
#  'rite': 1757,
#  'dun': 631,
#  'comin': 419,
#  'stori': 2010,
#  'person stori': 1541,
#  'rington': 1753,
#  'free rington': 792,
#  'repli real': 1726,
#  'st free': 1975,
#  'free join': 785,
#  'rest': 1740,
#  'project': 1641,
#  'wan meet': 2348,
#  'time make': 2149,
#  'izzit': 1078,
#  'mrt': 1397,
#  'congrat': 438,
#  'kano': 1107,
#  'poor': 1597,
#  'spk': 1963,
#  'sn': 1919,
#  'drop': 626,
#  'let': 1171,
#  'hr': 1016,
#  'prepar': 1619,
#  'tom': 2178,
#  'fact': 696,
#  'gay': 832,
#  'upload': 2266,
#  'gay chat': 833,
#  'call stop': 281,
#  'stop text': 2005,
#  'text call': 2111,
#  'wall': 2345,
#  'safe': 1780,
#  'break': 215,
#  'closer': 387,
#  'aha': 39,
#  'valentin': 2308,
#  'beauti': 153,
#  'aunti': 114,
#  'happi valentin': 945,
#  'valentin day': 2309,
#  'bird': 168,
#  'ur msg': 2289,
#  'sentenc': 1824,
#  'concentr': 433,
#  'career': 309,
#  'entri': 670,
#  'comp': 420,
#  'word': 2425,
#  'www': 2456,
#  'free entri': 784,
#  'entri weekli': 671,
#  'weekli comp': 2382,
#  'chanc': 334,
#  'discount': 596,
#  'voucher': 2329,
#  'savamob': 1787,
#  'member': 1302,
#  'cs': 494,
#  'sub': 2026,
#  'chanc claim': 335,
#  'claim ur': 377,
#  'ur worth': 2294,
#  'worth discount': 2439,
#  'discount voucher': 597,
#  'voucher today': 2335,
#  'today text': 2171,
#  'text savamob': 2117,
#  'savamob member': 1788,
#  'member offer': 1303,
#  'offer mobil': 1483,
#  'mobil cs': 1355,
#  'cs savamob': 498,
#  'savamob pobox': 1790,
#  'maid': 1254,
#  'murder': 1420,
#  'januari': 1082,
#  'govt': 884,
#  'includ': 1048,
#  'post': 1602,
#  'offic': 1486,
#  'understand': 2250,
#  'hous maid': 1011,
#  'murder coz': 1421,
#  'coz murder': 479,
#  'murder lt': 1422,
#  'gt januari': 905,
#  'januari public': 1083,
#  'holiday govt': 987,
#  'govt instituit': 885,
#  'close includ': 386,
#  'post offic': 1603,
#  'subscrib': 2028,
#  'deliv': 567,
#  'txt word': 2231,
#  'welcom': 2385,
#  'age': 37,
#  'weed': 2371,
#  'disturb': 601,
#  'brought': 223,
#  'warm': 2354,
#  'smile make': 1913,
#  'make feel': 1259,
#  'addi': 17,
#  'wed': 2369,
#  'arsen': 95,
#  'condit': 434,
#  'mean': 1290,
#  'escap': 674,
#  'movi': 1392,
#  'mind': 1327,
#  'bar': 141,
#  'send home': 1816,
#  'solv': 1927,
#  'found': 775,
#  'decim': 558,
#  'wife': 2398,
#  'polic': 1594,
#  'cook': 461,
#  'marriag': 1274,
#  'immedi': 1043,
#  'lt decim': 1237,
#  'decim gt': 559,
#  'taunton': 2080,
#  'guarante award': 916,
#  'ur award': 2270,
#  'award call': 123,
#  'call free': 255,
#  'gentl': 844,
#  'freemsg': 798,
#  'darl': 525,
#  'tb': 2081,
#  'std': 1989,
#  'rcv': 1672,
#  'bb': 148,
#  'tomorrow love': 2181,
#  'slow': 1903,
#  'fren': 800,
#  'film': 734,
#  'muz': 1425,
#  'yan': 2481,
#  'jiu': 1090,
#  'yan jiu': 2482,
#  'born': 199,
#  'god': 868,
#  'idiot': 1040,
#  'competit': 423,
#  'knew': 1125,
#  'forev': 766,
#  'laid': 1135,
#  'oop': 1493,
#  'roommat': 1764,
#  'lead': 1161,
#  'afternoon love': 35,
#  'love day': 1220,
#  'yahoo': 2480,
#  'messeng': 1316,
#  'send messag': 1817,
#  'messag send': 1313,
#  'receipt': 1690,
#  'roger': 1760,
#  'rem': 1710,
#  'omg': 1489,
#  'scream': 1797,
#  'weight': 2384,
#  'sipix': 1880,
#  'fromm': 815,
#  'landlin': 1139,
#  'deliveri': 570,
#  'camera award': 294,
#  'award sipix': 126,
#  'sipix digit': 1881,
#  'camera call': 295,
#  'call fromm': 258,
#  'fromm landlin': 816,
#  'landlin deliveri': 1142,
#  'deliveri day': 571,
#  'convinc': 460,
#  'read': 1678,
#  'cramp': 484,
#  'copi': 464,
#  'membership': 1304,
#  'cbe': 324,
#  'shop': 1851,
#  'citi': 369,
#  'updat': 2262,
#  'mth': 1411,
#  'rental': 1716,
#  'mth half': 1414,
#  'half price': 934,
#  'price orang': 1625,
#  'orang line': 1506,
#  'line rental': 1186,
#  'mobileupd call': 1368,
#  'pix': 1563,
#  'top': 2190,
#  'awesom': 128,
#  'left': 1166,
#  'sigh': 1869,
#  'studi': 2020,
#  'day love': 539,
#  'love start': 1228,
#  'yor': 2494,
#  'money': 1374,
#  'rent': 1715,
#  'fill': 733,
#  'stress': 2016,
#  'pay rent': 1535,
#  'call home': 260,
#  'helen': 965,
#  'mo': 1346,
#  'friendship': 810,
#  'forward': 773,
#  'evng': 679,
#  'friendship smile': 811,
#  'smile read': 1914,
#  'read forward': 1680,
#  'forward messag': 774,
#  'messag smile': 1314,
#  'smile gud': 1912,
#  'gud evng': 921,
#  'role': 1761,
#  'stand': 1978,
#  'hold': 982,
#  'correct': 466,
#  'omw': 1490,
#  'tampa': 2075,
#  'omw back': 1491,
#  'daddi': 520,
#  'goodnight': 877,
#  'fix': 753,
#  'wake': 2343,
#  'dearli': 553,
#  'night sleep': 1451,
#  'luck': 1240,
#  'catch': 322,
#  'write': 2447,
#  'dictionari': 579,
#  'hand': 935,
#  'press': 1621,
#  'remov': 1714,
#  'interest': 1060,
#  'ur hand': 2277,
#  'club': 388,
#  'direct': 591,
#  'direct mobil': 592,
#  'mobil week': 1364,
#  'aight': 42,
#  'ahmad': 41,
#  'cardiff': 306,
#  'cold': 402,
#  'sit': 1885,
#  'pray': 1616,
#  'decid': 557,
#  'hungri': 1022,
#  'delet': 566,
#  'websit': 2368,
#  'fr': 776,
#  'clock': 384,
#  'nt': 1470,
#  'second': 1803,
#  'alwi': 55,
#  'cancer': 300,
#  'throat': 2132,
#  'monday': 1373,
#  'call call': 250,
#  'sell': 1811,
#  'pc': 1538,
#  'issu': 1075,
#  'lab': 1130,
#  'comput': 429,
#  'ship': 1845,
#  'address': 19,
#  'wtf': 2453,
#  'friday': 802,
#  'egg': 650,
#  'need': 1434,
#  'pilat': 1560,
#  'definit': 564,
#  'birthday': 169,
#  'transfer': 2201,
#  'cake': 243,
#  'cafe': 242,
#  'somethin': 1928,
#  'love friendship': 1221,
#  'ur friend': 2276,
#  'flirt': 759,
#  'boss': 200,
#  'fire': 750,
#  'phone number': 1550,
#  'call text': 282,
#  'email': 651,
#  'payment': 1536,
#  'explain': 691,
#  'weekend': 2378,
#  'back home': 133,
#  'great weekend': 894,
#  'oki': 1488,
#  'appt': 80,
#  'shame': 1840,
#  'hair': 931,
#  'imagin': 1041,
#  'cock': 395,
#  'water': 2360,
#  'lar': 1144,
#  'differ': 582,
#  'footbal': 765,
#  'park': 1525,
#  'cool text': 463,
#  'urself': 2303,
#  'tea': 2086,
#  'pleas': 1577,
#  'indian': 1051,
#  'save': 1791,
#  'respect': 1738,
#  'meet today': 1298,
#  'infern': 1052,
#  'affair': 29,
#  'darren': 527,
#  'mayb': 1288,
#  'wan watch': 2349,
#  'watch infern': 2358,
#  'infern affair': 1053,
#  'colour': 412,
#  'style': 2023,
#  'speed': 1959,
#  'notic': 1469,
#  'turn': 2219,
#  'freak': 777,
#  'thursday': 2136,
#  'pick phone': 1556,
#  'phone pl': 1552,
#  'pl send': 1571,
#  'mnth': 1345,
#  'txt call': 2223,
#  'congratul': 439,
#  'xma': 2471,
#  'minut': 1329,
#  'congratul friend': 440,
#  'friend xma': 809,
#  'xma prize': 2472,
#  'call minut': 267,
#  'minut bt': 1330,
#  'lunch': 1244,
#  'air': 43,
#  'run': 1774,
#  'cell': 329,
#  'wait day': 2341,
#  'end': 654,
#  'ladi': 1134,
#  'march end': 1270,
#  'arrang': 91,
#  'soni': 1930,
#  'min txt': 1325,
#  'free bluetooth': 780,
#  'phone call': 1547,
#  'woke': 2421,
#  'fall': 699,
#  'asleep': 102,
#  'coupl': 473,
#  'coupl minut': 474,
#  'singl': 1879,
#  'text age': 2109,
#  'success': 2030,
#  'morn dear': 1382,
#  'horribl': 1004,
#  'bf': 164,
#  'shd': 1842,
#  'content': 455,
#  'pg': 1543,
#  'refer': 1704,
#  'ju': 1101,
#  'gift': 851,
#  'auto': 115,
#  'sorri': 1935,
#  'xxxxxxx': 2478,
#  'tomo': 2179,
#  'invit': 1062,
#  'hurri': 1024,
#  'crash': 485,
#  'love life': 1224,
#  'free text': 794,
#  'free msg': 788,
#  'cinema': 368,
#  'drink': 624,
#  'tsunami': 2214,
#  'swim': 2065,
#  'sri': 1972,
#  'tat': 2079,
#  'askd': 99,
#  'store': 2008,
#  'video': 2317,
#  'handset': 937,
#  ...}

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
spam_detect_model=MultinomialNB()
spam_detect_model.fit(X_train, y_train)
spam_detect_model
# Out:
# MultinomialNB()

# %%
y_pred=spam_detect_model.predict(X_test)

# %%
# performance metrics

from sklearn.metrics import confusion_matrix, classification_report
cm=confusion_matrix(y_pred=y_pred, y_true=y_test)
cr=classification_report(y_pred=y_pred, y_true=y_test)
print(cm)
print(cr)
# Out:
# [[1179   16]
#  [  16  182]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1195
#            1       0.92      0.92      0.92       198
#
#     accuracy                           0.98      1393
#    macro avg       0.95      0.95      0.95      1393
# weighted avg       0.98      0.98      0.98      1393

# %%
# Train, Test Split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(corpus, y, test_size=0.25, random_state=23)

# %%
# creating the TF-IDF model

from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer()
X_train=tfidf.fit_transform(X_train).toarray()
X_test=tfidf.transform(X_test).toarray()

# %%
tfidf.vocabulary_
# Out:
# {'fine': 1561,
#  'love': 2573,
#  'safe': 3770,
#  'ride': 3702,
#  'equal': 1385,
#  'unev': 4705,
#  'peski': 3255,
#  'cyclist': 1022,
#  'time': 4524,
#  'night': 2965,
#  'guarante': 1871,
#  'cash': 675,
#  'prize': 3445,
#  'claim': 791,
#  'yr': 5122,
#  'call': 631,
#  'custom': 1012,
#  'servic': 3879,
#  'repres': 3660,
#  'read': 3580,
#  'shame': 3902,
#  'take': 4370,
#  'run': 3757,
#  'blame': 466,
#  'long': 2544,
#  'neshanth': 2938,
#  'tel': 4414,
#  'wan': 4861,
#  'meet': 2712,
#  'pm': 3325,
#  'costa': 929,
#  'sol': 4082,
#  'holiday': 2018,
#  'await': 308,
#  'collect': 843,
#  'toclaim': 4551,
#  'sae': 3768,
#  'tc': 4399,
#  'pobox': 3329,
#  'stockport': 4224,
#  'sk': 4006,
#  'xh': 5064,
#  'cost': 928,
#  'max': 2689,
#  'min': 2751,
#  'hot': 2042,
#  'live': 2517,
#  'fantasi': 1492,
#  'ntt': 3019,
#  'box': 526,
#  'croydon': 978,
#  'cr': 951,
#  'wb': 4889,
#  'lanr': 2424,
#  'fakey': 1481,
#  'eckankar': 1314,
#  'detail': 1119,
#  'mail': 2637,
#  'nokia': 2988,
#  'colour': 846,
#  'phone': 3271,
#  'deliveredtomorrow': 1093,
#  'free': 1652,
#  'minut': 2763,
#  'mobil': 2796,
#  'text': 4446,
#  'camcord': 641,
#  'repli': 3657,
#  'jon': 2294,
#  'ive': 2235,
#  'spain': 4122,
#  'recent': 3599,
#  'hav': 1937,
#  'sum': 4299,
#  'dinero': 1153,
#  'left': 2462,
#  'bill': 446,
#  'ur': 4740,
#  'rent': 3650,
#  'mayb': 2692,
#  'interest': 2195,
#  'pe': 3223,
#  'tb': 4398,
#  'jame': 2247,
#  'urgent': 4744,
#  'number': 3025,
#  'award': 310,
#  'land': 2417,
#  'line': 2498,
#  'valid': 4771,
#  'hr': 2058,
#  'kalli': 2334,
#  'inning': 2175,
#  'tv': 4653,
#  'avail': 300,
#  'work': 5011,
#  'place': 3303,
#  'make': 2641,
#  'smokin': 4057,
#  'chikku': 755,
#  'room': 3729,
#  'nw': 3034,
#  'bu': 588,
#  'tomorrow': 4569,
#  'abt': 19,
#  'tht': 4509,
#  'guy': 1885,
#  'stop': 4231,
#  'irrit': 2220,
#  'msging': 2853,
#  'half': 1903,
#  'prepar': 3415,
#  'congrat': 891,
#  'treat': 4617,
#  'pend': 3232,
#  'day': 1052,
#  'respect': 3672,
#  'mother': 2832,
#  'home': 2020,
#  'check': 731,
#  'footbal': 1618,
#  'back': 325,
#  'sky': 4016,
#  'gamestar': 1718,
#  'activ': 44,
#  'play': 3311,
#  'dream': 1245,
#  'team': 4404,
#  'score': 3825,
#  'start': 4192,
#  'saturday': 3806,
#  'regist': 3625,
#  'opt': 3104,
#  'buy': 613,
#  'lunch': 2599,
#  'eat': 1307,
#  'maggi': 2630,
#  'mee': 2711,
#  'si': 3966,
#  'juz': 2323,
#  'watch': 4877,
#  'italian': 2226,
#  'job': 2283,
#  'hey': 1981,
#  'compani': 860,
#  'elama': 1338,
#  'mudyadhu': 2866,
#  'sorri': 4105,
#  'thing': 4483,
#  'pub': 3497,
#  'pick': 3281,
#  'spoon': 4160,
#  'sort': 4107,
#  'code': 833,
#  'acc': 24,
#  'bank': 344,
#  'natwest': 2915,
#  'confirm': 887,
#  'person': 3249,
#  'fundament': 1698,
#  'cool': 914,
#  'life': 2483,
#  'walk': 4855,
#  'king': 2372,
#  'gud': 1873,
#  'whatsup': 4934,
#  'sleep': 4023,
#  'msg': 2852,
#  'offic': 3059,
#  'worri': 5017,
#  'derek': 1108,
#  'taylor': 4396,
#  'assum': 265,
#  'worst': 5019,
#  'piss': 3297,
#  'talk': 4373,
#  'realis': 3585,
#  'point': 3337,
#  'backward': 326,
#  'quit': 3533,
#  'hope': 2033,
#  'stress': 4246,
#  'gr': 1829,
#  'congratul': 892,
#  'cd': 688,
#  'gift': 1768,
#  'voucher': 4836,
#  'entri': 1376,
#  'weekli': 4909,
#  'draw': 1243,
#  'txt': 4662,
#  'music': 2880,
#  'tnc': 4546,
#  'www': 5056,
#  'ldew': 2449,
#  'win': 4961,
#  'ppmx': 3391,
#  'age': 92,
#  'photo': 3274,
#  'shoot': 3938,
#  'spif': 4141,
#  'fun': 1695,
#  'workag': 5012,
#  'today': 4552,
#  'optout': 3107,
#  'gbp': 1738,
#  'mtmsg': 2860,
#  'dear': 1058,
#  'lt': 2588,
#  'gt': 1867,
#  'dollar': 1215,
#  'test': 4443,
#  'cooki': 913,
#  'jelli': 2266,
#  'superb': 4311,
#  'grate': 1842,
#  'mean': 2700,
#  'opportun': 3101,
#  'happier': 1924,
#  'result': 3681,
#  'engag': 1361,
#  'fixd': 1577,
#  'month': 2818,
#  'shock': 3936,
#  'bt': 585,
#  'njan': 2981,
#  'vilikkam': 4807,
#  'ws': 5045,
#  'sudn': 4289,
#  'videophon': 4802,
#  'videochat': 4801,
#  'wid': 4951,
#  'mate': 2680,
#  'java': 2257,
#  'game': 1717,
#  'dload': 1193,
#  'polyph': 3348,
#  'nolin': 2989,
#  'rentl': 3652,
#  'goodmorn': 1809,
#  'send': 3865,
#  'apologet': 198,
#  'fallen': 1485,
#  'actin': 42,
#  'spoilt': 4155,
#  'child': 756,
#  'caught': 682,
#  'badli': 328,
#  'cheer': 736,
#  'contact': 901,
#  'weekend': 4908,
#  'show': 3952,
#  'doll': 1214,
#  'patrick': 3208,
#  'swayz': 4340,
#  'great': 1849,
#  'funk': 1700,
#  'fone': 1613,
#  'tone': 4571,
#  'rington': 3708,
#  'co': 826,
#  'uk': 4683,
#  'origin': 3123,
#  'network': 2944,
#  'oper': 3098,
#  'rate': 3567,
#  'appli': 205,
#  'manag': 2647,
#  'wednesday': 4904,
#  'babi': 321,
#  'sat': 3800,
#  'bloodi': 481,
#  'mo': 2791,
#  'wanna': 4863,
#  'somethin': 4087,
#  'ortxt': 3125,
#  'jess': 2273,
#  'xx': 5069,
#  'aight': 105,
#  'grab': 1830,
#  'ring': 3707,
#  'costum': 930,
#  'futur': 1705,
#  'yowif': 5121,
#  'hint': 1991,
#  'luck': 2593,
#  'feb': 1516,
#  'remov': 3647,
#  'mth': 2859,
#  'updat': 4733,
#  'orang': 3110,
#  'latest': 2435,
#  'camera': 642,
#  'unlimit': 4719,
#  'upd': 4732,
#  'freefon': 1655,
#  'stoptxt': 4235,
#  'money': 2811,
#  'carlo': 668,
#  'madam': 2623,
#  'regret': 3627,
#  'disturb': 1183,
#  'receiv': 3597,
#  'refer': 3615,
#  'dlf': 1192,
#  'premarica': 3411,
#  'kindli': 2371,
#  'inform': 2169,
#  'rgd': 3694,
#  'rakhesh': 3552,
#  'kerala': 2353,
#  'trust': 4635,
#  'cbe': 686,
#  'pay': 3214,
#  'challeng': 707,
#  'puriti': 3506,
#  'friendship': 1670,
#  'smile': 4053,
#  'forward': 1637,
#  'messag': 2733,
#  'evng': 1424,
#  'musthu': 2883,
#  'gsoh': 1866,
#  'spam': 4123,
#  'ladi': 2409,
#  'male': 2644,
#  'gigolo': 1770,
#  'join': 2289,
#  'fastest': 1499,
#  'grow': 1861,
#  'men': 2725,
#  'club': 818,
#  'oncal': 3085,
#  'mjzgroup': 2781,
#  'rcvd': 3575,
#  'master': 2677,
#  'bb': 373,
#  'bf': 433,
#  'privat': 3443,
#  'account': 33,
#  'statement': 4197,
#  'redeem': 3612,
#  'identifi': 2109,
#  'expir': 1453,
#  'freez': 1659,
#  'rememb': 3642,
#  'kiss': 2376,
#  'mom': 2808,
#  'morn': 2823,
#  'miss': 2769,
#  'gotta': 1824,
#  'hit': 1996,
#  'decid': 1067,
#  'loxahatche': 2582,
#  'xma': 5065,
#  'tree': 4619,
#  'burn': 606,
#  'total': 4590,
#  'star': 4188,
#  'comp': 859,
#  'word': 5010,
#  'enter': 1370,
#  'textcomp': 4450,
#  'cust': 1010,
#  'ugh': 4678,
#  'fuck': 1686,
#  'resub': 3680,
#  'eve': 1411,
#  'film': 1552,
#  'imma': 2129,
#  'jay': 2258,
#  'drug': 1261,
#  'stori': 4237,
#  'cancer': 649,
#  'big': 442,
#  'deal': 1056,
#  'regular': 3628,
#  'checkup': 734,
#  'aka': 115,
#  'pap': 3178,
#  'smear': 4049,
#  'lar': 2427,
#  'stock': 4223,
#  'comin': 853,
#  'video': 4800,
#  'ppm': 3389,
#  'ave': 303,
#  'vari': 4774,
#  'close': 812,
#  'post': 3371,
#  'bcm': 380,
#  'ldn': 2450,
#  'wc': 4890,
#  'sunshin': 4308,
#  'quiz': 3534,
#  'super': 4310,
#  'soni': 4094,
#  'dvd': 1289,
#  'record': 3605,
#  'cannam': 652,
#  'capit': 656,
#  'australia': 295,
#  'mquiz': 2844,
#  'bore': 513,
#  'lectur': 2461,
#  'repeat': 3654,
#  'week': 4907,
#  'stuff': 4269,
#  'wast': 4875,
#  'tour': 4594,
#  'sofa': 4077,
#  'curiou': 1006,
#  'sugar': 4293,
#  'bath': 365,
#  'ouch': 3131,
#  'wish': 4975,
#  'stay': 4200,
#  'bit': 457,
#  'longer': 2545,
#  'forgot': 1630,
#  'smth': 4063,
#  'section': 3848,
#  'clearer': 805,
#  'loosu': 2555,
#  'hospit': 2038,
#  'careless': 665,
#  'avatar': 302,
#  'suppos': 4319,
#  'subtoitl': 4283,
#  'anthoni': 182,
#  'bring': 560,
#  'school': 3822,
#  'fee': 1520,
#  'friend': 1668,
#  'immedi': 2130,
#  'wait': 4852,
#  'dri': 1249,
#  'spell': 4136,
#  'season': 3840,
#  'bodi': 495,
#  'progress': 3463,
#  'pl': 3302,
#  'continu': 904,
#  'armand': 235,
#  'order': 3113,
#  'charg': 718,
#  'arriv': 241,
#  'red': 3611,
#  'txtstar': 4667,
#  'mobi': 2795,
#  'high': 1986,
#  'street': 4245,
#  'duchess': 1272,
#  'cornwal': 920,
#  'unsub': 4727,
#  'sp': 4119,
#  'lil': 2493,
#  'fever': 1532,
#  'wiskey': 4977,
#  'brandi': 539,
#  'rum': 3754,
#  'gin': 1773,
#  'beer': 401,
#  'vodka': 4828,
#  'scotch': 3826,
#  'shampain': 3903,
#  'wine': 4966,
#  'kudi': 2400,
#  'yarasu': 5085,
#  'dhina': 1129,
#  'vaazhthukk': 4768,
#  'approx': 212,
#  'jot': 2299,
#  'hiya': 2001,
#  'spoken': 4157,
#  'christma': 781,
#  'occas': 3048,
#  'celebr': 693,
#  'reflect': 3617,
#  'valu': 4772,
#  'desir': 1114,
#  'affect': 79,
#  'amp': 153,
#  'tradit': 4603,
#  'ideal': 2107,
#  'understand': 4699,
#  'idea': 2106,
#  'slurp': 4041,
#  'happi': 1923,
#  'alright': 133,
#  'usf': 4755,
#  'guess': 1876,
#  'car': 659,
#  'logo': 2536,
#  'question': 3529,
#  'info': 2168,
#  'meant': 2703,
#  'joke': 2290,
#  'light': 2488,
#  'sing': 3991,
#  'import': 2136,
#  'find': 1560,
#  'femal': 1529,
#  'prefer': 3409,
#  'citizen': 787,
#  'smart': 4045,
#  'navig': 2919,
#  'choos': 773,
#  'plan': 3306,
#  'requir': 3663,
#  'guidanc': 1879,
#  'doubt': 1232,
#  'especi': 1398,
#  'girl': 1774,
#  'email': 1347,
#  'id': 2104,
#  'fight': 1546,
#  'world': 5016,
#  'easi': 1300,
#  'lose': 2556,
#  'fightng': 1547,
#  'dificult': 1147,
#  'gam': 1715,
#  'outstand': 3142,
#  'technic': 4408,
#  'support': 4318,
#  'voic': 4829,
#  'process': 3455,
#  'uworld': 4766,
#  'site': 4000,
#  'qbank': 3520,
#  'assess': 261,
#  'toshiba': 4588,
#  'porteg': 3365,
#  'gd': 1739,
#  'engalnd': 1362,
#  'telli': 4419,
#  'elliot': 1344,
#  'damn': 1030,
#  'ju': 2307,
#  'finish': 1563,
#  'auction': 287,
#  'subscript': 4280,
#  'msgrcvd': 2854,
#  'skip': 4014,
#  'unsubscrib': 4728,
#  'customercar': 1013,
#  'hous': 2049,
#  'swoop': 4351,
#  'bird': 450,
#  'hurri': 2077,
#  'soup': 4112,
#  'sound': 4111,
#  'finger': 1562,
#  'difficult': 1145,
#  'type': 4672,
#  'welcom': 4916,
#  'gender': 1745,
#  'begin': 406,
#  'chicken': 752,
#  'late': 2433,
#  'woould': 5007,
#  'buzz': 617,
#  'hear': 1956,
#  'size': 4005,
#  'babe': 320,
#  'bread': 542,
#  'milk': 2747,
#  'give': 1778,
#  'year': 5091,
#  'access': 27,
#  'news': 2953,
#  'sport': 4161,
#  'term': 4433,
#  'ow': 3152,
#  'gonna': 1806,
#  'burger': 604,
#  'move': 2839,
#  'pain': 3165,
#  'kill': 2368,
#  'sir': 3996,
#  'group': 1860,
#  'mandi': 2651,
#  'sullivan': 4298,
#  'hotmix': 2045,
#  'fm': 1602,
#  'chosen': 777,
#  'easter': 1306,
#  'telephon': 4416,
#  'transfer': 4609,
#  'combin': 848,
#  'part': 3194,
#  'rest': 3676,
#  'project': 3464,
#  'gentleman': 1751,
#  'digniti': 1150,
#  'alrit': 134,
#  'jod': 2286,
#  'how': 2050,
#  'revis': 3691,
#  'goin': 1797,
#  'keri': 2355,
#  'doin': 1210,
#  'smidgin': 4052,
#  'colleg': 844,
#  'beauti': 389,
#  'necklac': 2927,
#  'token': 4557,
#  'heart': 1959,
#  'wife': 4954,
#  'like': 2491,
#  'garbag': 1724,
#  'bag': 329,
#  'egg': 1331,
#  'hannaford': 1917,
#  'wheat': 4935,
#  'chex': 747,
#  'food': 1615,
#  'fridg': 1667,
#  'meal': 2699,
#  'tonight': 4573,
#  'keen': 2347,
#  'kind': 2369,
#  'feel': 1522,
#  'tomo': 4567,
#  'mind': 2753,
#  'build': 597,
#  'snowman': 4074,
#  'snow': 4071,
#  'angel': 164,
#  'snowbal': 4072,
#  'noon': 2993,
#  'enjoy': 1366,
#  'yesterday': 5100,
#  'touch': 4591,
#  'fondli': 1612,
#  'bein': 410,
#  'thot': 4496,
#  'abiola': 11,
#  'oga': 3063,
#  'listen': 2512,
#  'plaid': 3305,
#  'album': 117,
#  'air': 106,
#  'hilari': 1988,
#  'bought': 521,
#  'braindanc': 535,
#  'ofstuff': 3062,
#  'aphex': 195,
#  'abel': 7,
#  'sn': 4064,
#  'xxxx': 5074,
#  'lab': 2404,
#  'becoz': 392,
#  'jan': 2250,
#  'whn': 4943,
#  'ofic': 3061,
#  'cn': 821,
#  'fr': 1645,
#  'duffer': 1276,
#  'blake': 465,
#  'address': 53,
#  'want': 4865,
#  'lost': 2559,
#  'answer': 177,
#  'gent': 1749,
#  'luv': 2604,
#  'surf': 4324,
#  'onlin': 3088,
#  'store': 4236,
#  'offer': 3058,
#  'flake': 1580,
#  'shit': 3929,
#  'roommat': 3731,
#  'batteri': 369,
#  'mr': 2845,
#  'adewal': 54,
#  'uncl': 4693,
#  'egbon': 1330,
#  'wudn': 5051,
#  'notic': 3006,
#  'taunton': 4392,
#  'theatr': 4464,
#  'upto': 4738,
#  'standard': 4186,
#  'wire': 4972,
#  'net': 2939,
#  'st': 4179,
#  'uz': 4767,
#  'mobcudb': 2794,
#  'drink': 1250,
#  'water': 4881,
#  'daili': 1028,
#  'wonder': 5004,
#  'wkend': 4985,
#  'journey': 2300,
#  'terribl': 4437,
#  'wk': 4984,
#  'huge': 2067,
#  'mark': 2664,
#  'reach': 3577,
#  'awesom': 312,
#  'wereth': 4924,
#  'monkeespeopl': 2812,
#  'monkeyaround': 2814,
#  'howdi': 2053,
#  'gorgeou': 1817,
#  'howu': 2054,
#  'foundurself': 1639,
#  'jobyet': 2284,
#  'sausag': 3808,
#  'jen': 2267,
#  'xxx': 5072,
#  'open': 3096,
#  'wahala': 4846,
#  'chechi': 730,
#  'greet': 1854,
#  'westlif': 4928,
#  'current': 1007,
#  'unbreak': 4692,
#  'untam': 4729,
#  'unkempt': 4717,
#  'std': 4202,
#  'lib': 2477,
#  'gloucesterroad': 1786,
#  'uup': 4763,
#  'chat': 726,
#  'hg': 1983,
#  'suit': 4296,
#  'row': 3736,
#  'hl': 2002,
#  'balanc': 335,
#  'uptown': 4739,
#  'instead': 2189,
#  'lot': 2560,
#  'dearer': 1059,
#  'tallent': 4377,
#  'excit': 1435,
#  'spend': 4137,
#  'tmr': 4543,
#  'nite': 2977,
#  'price': 3435,
#  'rental': 3651,
#  'cross': 976,
#  'ntwk': 3020,
#  'mobileupd': 2799,
#  'cartoon': 673,
#  'templ': 4425,
#  'church': 783,
#  'txttowin': 4669,
#  'drivin': 1255,
#  'neva': 2945,
#  'develop': 1123,
#  'deu': 1122,
#  'earli': 1295,
#  'dinner': 1155,
#  'song': 4093,
#  'dedic': 1073,
#  'valuabl': 4773,
#  'frnd': 1674,
#  'rpli': 3741,
#  'hme': 2004,
#  'loan': 2527,
#  'purpos': 3508,
#  'homeown': 2021,
#  'tenant': 4427,
#  'previous': 3433,
#  'refus': 3622,
#  'full': 1692,
#  'handl': 1910,
#  'victoria': 4799,
#  'island': 2224,
#  'traffic': 4604,
#  'due': 1275,
#  'contract': 905,
#  'mnth': 2790,
#  'motorola': 2836,
#  'doubl': 1229,
#  'tariff': 4384,
#  'callback': 632,
#  'japanes': 2255,
#  'proverb': 3483,
#  'indian': 2159,
#  'version': 4791,
#  'leav': 2459,
#  'final': 1556,
#  'strike': 4251,
#  'happen': 1920,
#  'quiet': 3532,
#  'beth': 426,
#  'aunt': 293,
#  'charli': 721,
#  'helen': 1970,
#  'qualiti': 3527,
#  'complain': 866,
#  'aiyar': 111,
#  'hard': 1927,
#  'scold': 3824,
#  'hurt': 2078,
#  'prasanth': 3402,
#  'ettan': 1405,
#  'pass': 3201,
#  'away': 311,
#  'pray': 3404,
#  'famili': 1487,
#  'asu': 270,
#  'ppl': 3387,
#  'randomli': 3561,
#  'reformat': 3619,
#  'polyh': 3347,
#  'bx': 619,
#  'ip': 2212,
#  'receipt': 3596,
#  'earlier': 1296,
#  'uniform': 4711,
#  'chase': 724,
#  'syllabu': 4355,
#  'polo': 3345,
#  'london': 2541,
#  'busi': 610,
#  'moment': 2809,
#  'market': 2665,
#  'tape': 4383,
#  'pple': 3388,
#  'hee': 1965,
#  'infern': 2166,
#  'affair': 78,
#  'shuhui': 3963,
#  'oso': 3127,
#  'evo': 1425,
#  'download': 1236,
#  'flash': 1582,
#  'jealou': 2263,
#  'err': 1390,
#  'cud': 998,
#  'mid': 2740,
#  'februari': 1517,
#  'lect': 2460,
#  'hour': 2047,
#  'shop': 3939,
#  'spree': 4166,
#  'skilgm': 4008,
#  'tsc': 4639,
#  'winawk': 4963,
#  'perweeksub': 3253,
#  'atleast': 275,
#  'shakespear': 3901,
#  'shesil': 3917,
#  'appl': 203,
#  'pair': 3167,
#  'malarki': 2643,
#  'garden': 1725,
#  'readi': 3582,
#  'summer': 4301,
#  'select': 3857,
#  'bulb': 599,
#  'seed': 3851,
#  'worth': 5020,
#  'scotsman': 3828,
#  'notxt': 3010,
#  'wow': 5028,
#  'sooo': 4099,
#  'bare': 351,
#  'stand': 4185,
#  'fault': 1505,
#  'leg': 2463,
#  'musta': 2882,
#  'overdid': 3147,
#  'india': 2158,
#  'sad': 3767,
#  'nt': 3016,
#  'parent': 3190,
#  'kid': 2365,
#  'colleagu': 842,
#  'cup': 1004,
#  'sleepwel': 4026,
#  'googl': 1815,
#  'map': 2657,
#  'dorm': 1223,
#  'ft': 1685,
#  'hold': 2014,
#  'bout': 523,
#  'doc': 1198,
#  'nice': 2959,
#  'shirt': 3928,
#  'hubbi': 2064,
#  'fite': 1575,
#  'budget': 592,
#  'load': 2526,
#  'card': 660,
#  'abi': 9,
#  'hw': 2084,
#  'mj': 2780,
#  'studi': 4265,
#  'lazi': 2445,
#  'anniversari': 170,
#  'parti': 3195,
#  'tarpon': 4386,
#  'spring': 4167,
#  'okey': 3069,
#  'dokey': 1213,
#  'handset': 1911,
#  'anytim': 191,
#  'deliveri': 1094,
#  'competit': 865,
#  'definit': 1084,
#  'block': 474,
#  'breaker': 545,
#  'delux': 1096,
#  'format': 1635,
#  'featur': 1515,
#  'graphic': 1840,
#  'bbdelux': 375,
#  'yep': 5097,
#  'birthday': 455,
#  'praveesh': 3403,
#  'book': 505,
#  'delici': 1091,
#  'convert': 909,
#  'put': 3513,
#  'wall': 4857,
#  'care': 663,
#  'break': 544,
#  'closer': 813,
#  'goodnoon': 1812,
#  'bonu': 502,
#  'caller': 635,
#  'attempt': 280,
#  'nation': 2911,
#  'dun': 1280,
#  'bluff': 488,
#  'leh': 2466,
#  'boy': 527,
#  'made': 2624,
#  'problem': 3450,
#  'singl': 3992,
#  'chart': 723,
#  'top': 4581,
#  'actor': 45,
#  'even': 1413,
#  'unemploy': 4704,
#  'interview': 2200,
#  'torch': 4586,
#  'bold': 497,
#  'hip': 1992,
#  'hop': 2032,
#  'haha': 1895,
#  'jazz': 2261,
#  'zoom': 5138,
#  'kb': 2346,
#  'lesson': 2473,
#  'tire': 4528,
#  'special': 4130,
#  'gram': 1834,
#  'eighth': 1333,
#  'smarter': 4047,
#  'gibb': 1767,
#  'unsold': 4725,
#  'mike': 2743,
#  'hussey': 2080,
#  'fri': 1665,
#  'tom': 4564,
#  'mention': 2727,
#  'chines': 766,
#  'sindu': 3990,
#  'birla': 451,
#  'soft': 4078,
#  'user': 4754,
#  'lucki': 2594,
#  'http': 2062,
#  'urawinn': 4741,
#  'fantast': 1493,
#  'surpris': 4327,
#  'height': 1968,
#  'recycl': 3610,
#  'earn': 1298,
#  'spent': 4138,
#  'excel': 1434,
#  'display': 1180,
#  'wake': 4854,
#  'rite': 3712,
#  'sq': 4170,
#  'ard': 223,
#  'afternoon': 88,
#  'dawn': 1051,
#  'refresh': 3620,
#  'aliv': 128,
#  'breath': 547,
#  'bitch': 458,
#  'yan': 5083,
#  'jiu': 2280,
#  'liao': 2476,
#  'bugi': 596,
#  'vill': 4808,
#  'frm': 1672,
#  'parco': 3189,
#  'nb': 2920,
#  'sun': 4303,
#  'orc': 3111,
#  'mrt': 2849,
#  ...}

# %%
# training our model

from sklearn.naive_bayes import MultinomialNB
spam_detect_model_tfidf=MultinomialNB()
spam_detect_model_tfidf.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# making predictions

y_pred=spam_detect_model_tfidf.predict(X_test)

# %%
# performance evaluation

from sklearn.metrics import confusion_matrix, classification_report
cm=confusion_matrix(y_pred=y_pred, y_true=y_test)
cr=classification_report(y_pred=y_pred, y_true=y_test)
print(cm)
print(cr)
# Out:
# [[1206    1]
#  [  41  145]]
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1207
#            1       0.99      0.78      0.87       186
#
#     accuracy                           0.97      1393
#    macro avg       0.98      0.89      0.93      1393
# weighted avg       0.97      0.97      0.97      1393
